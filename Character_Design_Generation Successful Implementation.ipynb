# %%
# !pip install psutil GPUtil
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=3058ad74e78b193c9100855293463bd0214d1d2fc6394d006b438adfc49f9ef3
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built GPUtil
# ...

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Unzip the project files
# !unzip /content/drive/MyDrive/sdxl-character-design.zip -d /content/

# Install dependencies
# !pip install -r /content/sdxl-character-design/requirements.txt

# Run the project
# %cd /content/sdxl-character-design/src
# !python main.py
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/MyDrive/sdxl-character-design.zip
#    creating: /content/sdxl-character-design/
#   inflating: /content/sdxl-character-design/.DS_Store
#   inflating: /content/__MACOSX/sdxl-character-design/._.DS_Store
#   inflating: /content/sdxl-character-design/requirements.txt
#    creating: /content/sdxl-character-design/config/
#   inflating: /content/sdxl-character-design/README.md
#    creating: /content/sdxl-character-design/.git/
#    creating: /content/sdxl-character-design/src/
#   inflating: /content/sdxl-character-design/config/config.yaml
#   inflating: /content/sdxl-character-design/.git/config
#    creating: /content/sdxl-character-design/.git/objects/
#   inflating: /content/sdxl-character-design/.git/HEAD
#    creating: /content/sdxl-character-design/.git/info/
#    creating: /content/sdxl-character-design/.git/logs/
#   inflating: /content/sdxl-character-design/.git/description
# ...
